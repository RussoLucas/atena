# %%
import pandas as pd

PATH = "AVT-Proficiency-SY-2021-22-Masked.xlsx"
FILE_NAME = ""

try:
    df = pd.read_excel(PATH)

    # print(df)
    
    if not df.empty:
        print("File read successfully.")
        display(df)  # Display the first few rows of the DataFrame
    
except FileNotFoundError:
    print("Error: File 'AVT-Proficiency-SY-2022-23-Masked.xlsx' not found in the current directory.")
    
except Exception as e:
    print(f"An error occurred: {str(e)}")
# Out:
# File read successfully.
#      All Valid Assessments, SY 2021-22, ESSA-aligned, FERPA-compliant  \
# 0      In order to meet confidentiality requirements...
# 1                                                  Code
# 2                                                     1
# 3                                                     1
# 4                                                     1
# ...                                                 ...
# 8863                                             999999
# 8864                                             999999
# 8865                                             999999
# 8866                                             999999
# 8867  NM-PED, Assessment, Research, Evaluation, and ...
#
#              Unnamed: 1               Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                   NaN                      NaN        NaN        NaN
# 1     State or District                   School   SortCode      Group
# 2           ALBUQUERQUE  ALBUQUERQUE DIST OFFICE          1        All
# 3           ALBUQUERQUE  ALBUQUERQUE DIST OFFICE          4      White
# 4           ALBUQUERQUE  ALBUQUERQUE DIST OFFICE          5      Black
# ...                 ...                      ...        ...        ...
# 8863         New Mexico                Statewide          8     Native
# 8864         New Mexico                Statewide         10        FRL
# 8865         New Mexico                Statewide         12        SWD
# 8866         New Mexico                Statewide         13         EL
# 8867                NaN                      NaN        NaN        NaN
#
#      Unnamed: 5                Unnamed: 6 Unnamed: 7  \
# 0           ELA                       NaN       MATH
# 1         Count  Proficient\n & Above\n %      Count
# 2         38146                  0.362554      38190
# 3          7865                  0.609536       7865
# 4          2213                  0.299141       2221
# ...         ...                       ...        ...
# 8863      18721                   0.19593      18735
# 8864     113441                  0.278224     113475
# 8865      27957                  0.103266      27915
# 8866      29447                  0.129317      29492
# 8867        NaN                       NaN        NaN
#
#                     Unnamed: 8 Unnamed: 9               Unnamed: 10
# 0                          NaN    SCIENCE                       NaN
# 1     Proficient\n & Above\n %      Count  Proficient \n& Above \n%
# 2                     0.253417      16092                  0.341723
# 3                      0.48684       3346                  0.589062
# 4                     0.176497        921                  0.258415
# ...                        ...        ...                       ...
# 8863                  0.141233       8044                   0.21084
# 8864                    0.1908      46208                  0.261578
# 8865                  0.074548      11335                  0.104808
# 8866                  0.099383      11668                  0.111073
# 8867                       NaN        NaN                       NaN
#
# [8868 rows x 11 columns]

# %%
import pandas as pd

output_file = 'AVT-Proficiency-SY-2021-22-Cleaned.xlsx'
# Create a new DataFrame with rows up to the last row to keep
new_df = df.iloc[:805 + 1]

# Save the modified DataFrame to a new Excel file
new_df.to_excel(output_file, index=False)
